# %% [markdown]
# <a href="https://colab.research.google.com/github/B-DS-Research/B6_Research/blob/main/Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings, os, json
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import shap

# %%
from datetime import datetime

from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import *
from sklearn.inspection import permutation_importance

from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import (
    RandomForestClassifier, RandomForestRegressor,
    ExtraTreesClassifier, ExtraTreesRegressor,
    GradientBoostingClassifier, GradientBoostingRegressor
)

from xgboost import XGBClassifier, XGBRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from catboost import CatBoostClassifier, CatBoostRegressor


# ============================================================
# 1. SETTINGS
# These settings make plots look professional and create folders
# for outputs, figures, submissions and documentation.
# ============================================================

sns.set_theme(style="whitegrid", font_scale=1.1)

plt.rcParams["figure.figsize"] = (11, 6)
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["axes.titleweight"] = "bold"

for folder in ["figures", "submissions", "outputs", "documentation"]:
    os.makedirs(folder, exist_ok=True)


# ============================================================
# 2. CHANGE THESE DURING THE HACKATHON
# TRAIN_PATH = location of training dataset
# TEST_PATH = location of hidden test dataset
# TARGET = target column you are predicting
# ID_COL = ID column if the submission needs it
# ============================================================

TRAIN_PATH = "/content/train.csv"
TEST_PATH = "/content/test.csv"

TARGET = "target"       # Change this after seeing dataset
ID_COL = None           # Example: "id" if available
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_700/3165258917.py in <cell line: 0>()
#      19 from xgboost import XGBClassifier, XGBRegressor
#      20 from lightgbm import LGBMClassifier, LGBMRegressor
# ---> 21 from catboost import CatBoostClassifier, CatBoostRegressor
#      22
#      23
#
# ModuleNotFoundError: No module named 'catboost'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# ============================================================
# 3. TEAMWORK LOG
# This creates evidence for collaboration and project planning.
# Update member names during the hackathon.
# ============================================================

team_log = {
    "project": "Data Science Hackathon",
    "created_at": str(datetime.now()),
    "team_members": [
        "Tarun - EDA, modelling, final review",
        "Member 2 - preprocessing",
        "Member 3 - visualisation",
        "Member 4 - baseline models",
        "Member 5 - advanced models",
        "Member 6 - tuning and submissions",
        "Member 7 - XAI and presentation"
    ],
    "workflow": [
        "EDA",
        "Preprocessing",
        "Feature engineering",
        "Model comparison",
        "Cross-validation",
        "Hyperparameter tuning",
        "Explainable AI",
        "Final submissions"
    ],
    "github_notes": [
        "Commit every 20-30 minutes",
        "Use meaningful commit messages",
        "Upload final notebook to GitHub",
        "Include GitHub and Colab links on first slide"
    ]
}

with open("documentation/teamwork_log.json", "w") as f:
    json.dump(team_log, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_700/646932294.py in <cell line: 0>()
#      35 }
#      36
# ---> 37 with open("documentation/teamwork_log.json", "w") as f:
#      38     json.dump(team_log, f, indent=4)
#      39
#
# FileNotFoundError: [Errno 2] No such file or directory: 'documentation/teamwork_log.json'

# %%
# 4. LOAD DATA
# Reads train and test files into pandas DataFrames.
# ============================================================

train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

display(train_df.head())
display(test_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_700/3803200051.py in <cell line: 0>()
#       3 # ============================================================
#       4
# ----> 5 train_df = pd.read_csv(TRAIN_PATH)
#       6 test_df = pd.read_csv(TEST_PATH)
#       7
#
# NameError: name 'TRAIN_PATH' is not defined
